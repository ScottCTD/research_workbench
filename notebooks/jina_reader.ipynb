# %%
import requests

def jina_reader(url: str) -> str:
    response = requests.get(
        f"https://r.jina.ai/{url}",
        headers={
            "Accept": "application/json",
            "Authorization": "Bearer jina_b8379c22dd4c439e842780d5167e0eacIO6aM8jkTKfNK1g2isxW0aTT0FJB",
            "X-Retain-Images": "none"
        }
    )
    response.raise_for_status()
    return response.json()

# %%
jina_reader("https://www.jina.ai")
# Out:
# {'code': 200,
#  'status': 20000,
#  'data': {'title': 'Jina AI - Your Search Foundation, Supercharged.',
#   'description': 'Best-in-class embeddings, rerankers, web reader, deepsearch, small language models. Search AI for multilingual and multimodal data.',
#   'url': 'https://www.jina.ai/',
# ...

# %%
import json

print(json.dumps(_, indent=2))
# Out:
# {
#   "code": 200,
#   "status": 20000,
#   "data": {
#     "title": "Jina AI - Your Search Foundation, Supercharged.",
#     "description": "Best-in-class embeddings, rerankers, web reader, deepsearch, small language models. Search AI for multilingual and multimodal data.",
#     "url": "https://www.jina.ai/",
# ...
